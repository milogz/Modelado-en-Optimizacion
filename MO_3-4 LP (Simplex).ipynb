# %% [markdown]
# # Modelado en Optimización (IIND-2501)
#
# ## Lección 3.4: '*Overview*' del Método Simplex
#
# **Propósito.**
# - Visualizar iteraciones del Método Simplex: base $B$, no-base $N$, multiplicadores, costos reducidos, **dirección** y **longitud de paso**.
# - Desarrollar la intuición de *moverse de vértice en vértice* intercambiando variables básicas y no básicas.

# %% [markdown]
# ## 1. Representación estándar de un modelo de optimización lineal
#
# Partimos de un modelo de programación lineal en formato estándar:
#
# $$\max\; c^\top x$$
# $$\text{s.a.}$$
# $$A x = b,\;$$
# $$x\ge 0.$$
#
# Y lo separamos en partes **básica** y **no básica**:
#
# $$\max\; c_B^\top x_B$$
# $$\text{s.a.}$$
# $$B x_B + N x_N = b,\;$$
# $$x_B\ge 0,$$
# $$x_N\ge 0.$$

# %% [markdown]
# ## 2. Pasos del método Simplex
#
# 1. Dada una **base factible inicial** ($I_B$ y $I_N$), podemos calcular el valor de las variables básicas y la función objetivo.
#
#    $$x = \left[ \begin{array}{c} x_B \\ \hline x_N \end{array}\right] =
#     \left[
#     \begin{array}{c}
#     B^{-1}b \\
#     \hline
#     0
#     \end{array}
#     \right], \quad \quad z=c_B^{T}x_B$$
#
# 2. **Verificar optimalidad**: calcular *costos reducidos*. (Recordar $w^{T} = c_B^{T} B^{-1} $)
#    $$r = c_N - (c_B^{T} B^{-1}) N $$
#    $$r = c_N - w^{T} N$$
#    $$r_q = c_q - w^{T} a_q, \quad \forall q \in I_N$$
#
# Si existe al menos un $r_q > 0$ para maximización (o un $r_q < 0$ para minimización), la variable no básica `q` **entra a la base** (pues su $r_q$ promete una mejora en la función objetivo); de lo contrario, decretamos optimalidad y terminamos.

# %% [markdown]
# 3. **Definir dirección** a partir de la variable entrante $q$ (si la hay):
#
#     $$d^{q} = \left[ \begin{array}{c} d^{q}_B \\ \hline d^{q}_N \end{array}\right] =
#     \left[
#     \begin{array}{c}
#     -B^{-1} A_q \\
#     \hline
#     e_q
#     \end{array}
#     \right]$$

# %% [markdown]
# 4. **Longitud**: encontramos cuánto podemos avanzar en la dirección $d^q$ sin que ninguna variable se haga negativa (hasta que alguna se haga cero).
#
# $$
# \theta = \min_{j\in I_B} \left\{ \frac{-x_{j}}{d_{j}} \;\middle|\; d_{j} < 0 \right\}
# $$

# %% [markdown]
# Si ninguna componente de la dirección es negativa, el problema es **no acotado**.

# %% [markdown]
# 5. **Pivoteo**: efectuar el movimiento, actualizar los índices básicos y no básicos, y repetir.
#
# $$x_{t+1} = x_{t} + \theta d^q$$

# %% [markdown]
# #### Criterio de optimalidad por costos reducidos
#
# > **Definicion (Costos reducidos).** Dada una base $B$ con precios sombra $w = B^{-T}c_B$, el *costo reducido* de la variable no basica $j$ es $\bar{c}_j = c_j - w^T a_j$, donde $a_j$ es la columna $j$ de $A$.
#
# > **Criterio de optimalidad (maximizacion).** Si todos los costos reducidos son $\le 0$ (i.e., $\bar{c}_j \le 0$ para todo $j \notin B$), entonces la solucion basica factible actual es **optima**: no existe direccion de movimiento que mejore el objetivo.
#
# Este criterio es el corazon del metodo Simplex: en cada iteracion verificamos si algun costo reducido es positivo (lo que indica una direccion de mejora), y si no lo es, declaramos optimalidad.

# %% [markdown]
# ## 3. Implementación computacional demostrativa

# %%
import numpy as np
from helpers_simplex import simplex_interactivo

# %%
# Problema ejemplo: max 3x1 + 2x2
# s.a.  x1 +  x2 <= 6
#       x1 + 2x2 <= 8
#      2x1 +  x2 <= 8
#       x1, x2 >= 0

A = np.array([
    [1., 1., 1., 0., 0.],
    [1., 2., 0., 1., 0.],
    [2., 1., 0., 0., 1.],
])
b = np.array([6., 8., 8.])
c = np.array([3., 2., 0., 0., 0.])

# %%
# Base inicial: holguras {s1, s2, s3}
Bcols_init = [False, False, True, True, True]
var_names  = ['x1', 'x2', 's1', 's2', 's3']

simplex_interactivo(A, b, c, Bcols_init, var_names)

# %% [markdown]
# ---
#
# #### Resumen y conexion con la proxima leccion
#
# En esta leccion implementamos el **metodo Simplex** como una exploracion geometrica del poliedro factible:
#
# 1. **Evaluar la base actual** -- calcular la solucion basica $x_B = B^{-1}b$ y el valor del objetivo $z = c_B^T x_B$.
# 2. **Verificar optimalidad** -- si todos los costos reducidos $\bar{c}_j \le 0$, la solucion actual es optima.
# 3. **Moverse al vertice vecino** -- elegir la variable entrante (costo reducido mas positivo), calcular la direccion y longitud del paso (regla del minimo cociente), y actualizar la base.
#
# Hemos visto que el Simplex encuentra la solucion optima recorriendo vertices adyacentes que mejoran el objetivo. Pero, que informacion adicional podemos extraer de la solucion optima?
#
# En la **proxima leccion** estudiaremos la **dualidad**: todo LP tiene un *problema dual* asociado cuya solucion nos da los *precios sombra* (valor marginal de cada recurso). Estas cantidades, que ya aparecieron en nuestro analisis como $w = B^{-T}c_B$, tienen una interpretacion economica fundamental.
